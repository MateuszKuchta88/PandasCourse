# %% [markdown]
# # Calculator

# %% [markdown]
# ![Calculator_image.jpg](attachment:73dfaf42-8fa9-4b0e-8c72-6399f44eaa3a.jpg)

# %% [markdown]
# ## Addition

# %% [markdown]
# Please read the following: https://en.wikipedia.org/wiki/Addition

# %%
5+7
# Out:
# 12

# %%
a = 4

# %%
a
# Out:
# 4

# %%
b = 2
b
# Out:
# 2

# %%
c = a + b

# %%
c
# Out:
# 6
